# %%
import pandas as pd

# %%
d1 = pd.read_csv('N50_Beta0.1_K10_Buffer1-10-Old.csv')
d1.groupby(["ArrivalRate","RelayBuffer"]).mean()
# Out:
#                          Run  NumSources  CommnArrivalRate  NumCopies  \
# ArrivalRate RelayBuffer
# 0.685       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.686       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.687       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.688       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# ...

# %%
d2 = pd.read_csv('N50_Beta0.1_K10_Buffer1-10.csv')
d2.groupby(["ArrivalRate","RelayBuffer"]).mean()
# Out:
#                          Run  NumSources  CommnArrivalRate  NumCopies  \
# ArrivalRate RelayBuffer
# 0.685       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.686       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.687       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# 0.688       5            0.5         1.0              0.55       10.0
#             9            0.5         1.0              0.55       10.0
#             13           0.5         1.0              0.55       10.0
# ...
