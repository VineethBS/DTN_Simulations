# %%
import pandas as pd

# %% [markdown]
# We need to check for consistency in the results that we have obtained for the different delivery mechanisms. For the case of feedback, one would expect that the delivery mechanism would change the way in which the queueing delay behaves

# %%
cases = ["Feedback-FIFO-RD/","Feedback-Random-RD/","Feedback-LIFO-RD/"]

# %% [markdown]
# Cases with $B = 1$. There shouldn't be much difference here.

# %%
filename = "B1_N50_K5_Beta0.1_Lambda_005_135.csv"

d1 = pd.read_csv(cases[0] + filename)
avg1 = d1.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std1 = d1.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg1.columns = ["FIFO-Q", "FIFO-D"]
std1.columns = ["STD-FIFO-Q", "STD-FIFO-D"]

d2 = pd.read_csv(cases[1] + filename)
avg2 = d2.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std2 = d2.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg2.columns = ["R-Q", "R-D"]
std2.columns = ["STD-R-Q", "STD-R-D"]

d3 = pd.read_csv(cases[2] + filename)
avg3 = d3.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std3 = d3.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg3.columns = ["LIFO-Q", "LIFO-D"]
std3.columns = ["STD-LIFO-Q", "STD-LIFO-D"]

db = pd.concat([avg1, std1, avg2, std2, avg3, std3],axis = 1)

# %%
db
# Out:
#                  FIFO-Q    FIFO-D  STD-FIFO-Q  STD-FIFO-D         R-Q  \
# ArrivalRate
# 0.05           0.956464  2.389812    0.009513    0.033853    0.957174
# 0.10           0.996969  2.418066    0.011994    0.023308    0.995283
# 0.15           1.038782  2.417726    0.019017    0.024256    1.036769
# 0.20           1.087950  2.425980    0.027754    0.029382    1.086697
# 0.25           1.141088  2.435855    0.037727    0.031723    1.140635
# 0.30           1.206230  2.441731    0.051243    0.033922    1.204033
# 0.35           1.281670  2.452696    0.070927    0.038523    1.277929
# 0.40           1.369389  2.464224    0.088747    0.046593    1.362914
# 0.45           1.474123  2.470122    0.109807    0.051303    1.471459
# 0.50           1.601205  2.481737    0.153631    0.055975    1.606240
# 0.55           1.771008  2.489938    0.210618    0.061189    1.760109
# 0.60           1.986911  2.497434    0.285515    0.069988    1.987369
# 0.65           2.280583  2.504995    0.402123    0.070410    2.270869
# 0.70           2.692749  2.516739    0.599245    0.079301    2.671756
# 0.75           3.344084  2.521436    0.953931    0.083891    3.345778
# 0.80           4.554610  2.533282    1.759049    0.091130    4.513981
# 0.85           8.159945  2.536841    4.819910    0.095565    8.094701
# 0.90         131.305209  2.547545  163.235629    0.098395   98.260431
# 0.95         267.872084  2.550289  267.026576    0.110873  266.888052
# 1.00         258.168624  2.564244  248.512765    0.118173  256.051959
# 1.05         441.693142  2.573519   73.532964    0.116237  332.716584
# 1.10         458.778247  2.570132    7.630957    0.125057  454.402080
# 1.15         435.470525  2.565113    7.733926    0.116011  434.242003
# 1.20         415.552396  2.560201    7.818136    0.121079  415.618371
# 1.25         400.086869  2.557414   10.394404    0.118950  402.490585
# 1.30         382.288228  2.556461    7.369806    0.149887  382.841945
# 1.35         368.464482  2.565386    7.933535    0.123830  371.759831
#
#                   R-D     STD-R-Q   STD-R-D      LIFO-Q    LIFO-D  STD-LIFO-Q  \
# ArrivalRate
# 0.05         2.406846    0.009641  0.022952    0.958607  2.394920    0.011023
# 0.10         2.408347    0.013657  0.018802    0.994902  2.405680    0.012703
# 0.15         2.416122    0.019411  0.021743    1.039917  2.417745    0.017576
# 0.20         2.425106    0.028647  0.026291    1.084525  2.422189    0.032976
# 0.25         2.429694    0.039062  0.030026    1.138156  2.429167    0.037237
# 0.30         2.444179    0.054777  0.031545    1.202093  2.442311    0.057878
# 0.35         2.454356    0.070226  0.038789    1.273458  2.446292    0.073183
# 0.40         2.461705    0.090817  0.046877    1.365295  2.460820    0.094317
# 0.45         2.471258    0.118670  0.056241    1.470116  2.468552    0.129088
# 0.50         2.478759    0.163181  0.055065    1.599655  2.478660    0.166141
# 0.55         2.486643    0.202911  0.062093    1.749855  2.485355    0.214671
# 0.60         2.496274    0.289000  0.064075    1.952787  2.497027    0.296604
# 0.65         2.508828    0.420495  0.074307    2.244373  2.501090    0.430010
# 0.70         2.513396    0.619600  0.079539    2.666778  2.510219    0.642380
# 0.75         2.522278    1.026230  0.084653    3.306736  2.521389    1.017564
# 0.80         2.531038    1.782461  0.088016    4.598503  2.527451    1.950399
# 0.85         2.539974    4.919280  0.095645    8.166065  2.535277    5.106792
# 0.90         2.545573  112.347228  0.099844  148.879676  2.548498  184.566110
# 0.95         2.548726  266.696173  0.112069  265.898042  2.552884  266.028396
# 1.00         2.561640  248.906531  0.110302  255.590517  2.551847  250.585412
# 1.05         2.563658  163.343608  0.123733  281.275837  2.568757  205.325484
# 1.10         2.559733    7.712223  0.121088  455.416433  2.562773    3.671175
# 1.15         2.552926    9.464196  0.129963  434.310834  2.570449    8.484980
# 1.20         2.569465   10.471204  0.116326  420.816339  2.563440    7.742128
# 1.25         2.567510    9.714174  0.112578  399.738652  2.566605    5.932541
# 1.30         2.561210    8.067175  0.120627  384.801417  2.559152   10.963842
# 1.35         2.552983    9.211480  0.136425  368.697766  2.570318    7.268685
#
#              STD-LIFO-D
# ArrivalRate
# 0.05           0.035473
# 0.10           0.031810
# 0.15           0.026255
# 0.20           0.025231
# 0.25           0.031533
# 0.30           0.035526
# 0.35           0.042672
# 0.40           0.046319
# 0.45           0.051559
# 0.50           0.053919
# 0.55           0.059737
# 0.60           0.066944
# 0.65           0.066329
# 0.70           0.076832
# 0.75           0.080113
# 0.80           0.084939
# 0.85           0.088518
# 0.90           0.098545
# 0.95           0.101421
# 1.00           0.113604
# 1.05           0.110592
# 1.10           0.125502
# 1.15           0.129767
# 1.20           0.132432
# 1.25           0.107597
# 1.30           0.130802
# 1.35           0.113231

# %%
filename = "B1_N250_K20_Beta0.5_Lambda_03125_091875.csv"

d1 = pd.read_csv(cases[0] + filename)
avg1 = d1.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std1 = d1.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg1.columns = ["FIFO-Q", "FIFO-D"]
std1.columns = ["STD-FIFO-Q", "STD-FIFO-D"]

d2 = pd.read_csv(cases[1] + filename)
avg2 = d2.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std2 = d2.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg2.columns = ["R-Q", "R-D"]
std2.columns = ["STD-R-Q", "STD-R-D"]

d3 = pd.read_csv(cases[2] + filename)
avg3 = d3.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std3 = d3.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg3.columns = ["LIFO-Q", "LIFO-D"]
std3.columns = ["STD-LIFO-Q", "STD-LIFO-D"]

db = pd.concat([avg1, std1, avg2, std2, avg3, std3],axis = 1)

# %%
db
# Out:
#                 FIFO-Q    FIFO-D  STD-FIFO-Q  STD-FIFO-D        R-Q       R-D  \
# ArrivalRate
# 0.3125        0.128768  0.168376    0.001088    0.002092   0.128562  0.167501
# 0.6250        0.132009  0.168589    0.000840    0.001333   0.132110  0.168629
# 0.9375        0.135858  0.168866    0.000843    0.001788   0.135890  0.168931
# 1.2500        0.140148  0.169173    0.000967    0.001786   0.140090  0.169347
# 1.5625        0.144614  0.169812    0.001109    0.001727   0.144494  0.169787
# 1.8750        0.150064  0.170132    0.001397    0.002256   0.149500  0.170000
# 2.1875        0.155314  0.170648    0.001807    0.002446   0.155504  0.170749
# 2.5000        0.161653  0.171351    0.001940    0.002812   0.161670  0.171161
# 2.8125        0.168917  0.171712    0.002614    0.003374   0.168669  0.171399
# 3.1250        0.176804  0.172079    0.003120    0.003729   0.176637  0.172059
# 3.4375        0.186803  0.172727    0.003572    0.004191   0.186181  0.172482
# 3.7500        0.197301  0.173106    0.004635    0.004465   0.196876  0.173039
# 4.0625        0.210870  0.173787    0.005364    0.005217   0.208099  0.173328
# 4.3750        0.225151  0.174175    0.006738    0.005283   0.224101  0.173874
# 4.6875        0.243168  0.174620    0.009712    0.006093   0.241312  0.174466
# 5.0000        0.265774  0.175374    0.012774    0.006319   0.263561  0.174944
# 5.3125        0.292227  0.175891    0.015670    0.007016   0.290628  0.175423
# 5.6250        0.330635  0.176434    0.021506    0.007334   0.329345  0.175880
# 5.9375        0.382647  0.177247    0.031238    0.007788   0.376907  0.176472
# 6.2500        0.452100  0.177620    0.045566    0.008464   0.449715  0.177016
# 6.5625        0.571394  0.178180    0.077647    0.009250   0.566701  0.177842
# 6.8750        0.776773  0.179015    0.145375    0.009938   0.765612  0.178367
# 7.1875        1.320664  0.179338    0.424890    0.010142   1.270408  0.178772
# 7.5000        6.817300  0.179953    6.868301    0.010898   7.971497  0.179544
# 7.8125       36.286104  0.180679   28.651343    0.011436  34.162021  0.180057
# 8.1250       61.836500  0.180516    0.626760    0.011770  61.575884  0.179867
# 8.4375       59.310501  0.180713    0.972034    0.011451  59.210849  0.180367
# 8.7500       57.285674  0.180715    0.971011    0.012279  57.097368  0.180034
# 9.0625       55.225954  0.180977    1.189326    0.011358  55.042149  0.179591
# 9.3750       53.571604  0.180821    0.759131    0.011883  53.446652  0.180298
#
#                STD-R-Q   STD-R-D     LIFO-Q    LIFO-D  STD-LIFO-Q  STD-LIFO-D
# ArrivalRate
# 0.3125        0.000804  0.002385   0.128577  0.167650    0.000813    0.002074
# 0.6250        0.000890  0.001440   0.131820  0.168488    0.001022    0.001434
# 0.9375        0.001066  0.001319   0.135955  0.169003    0.001097    0.001192
# 1.2500        0.001042  0.001582   0.140004  0.169386    0.001093    0.001707
# 1.5625        0.001125  0.002147   0.144228  0.169571    0.001426    0.001730
# 1.8750        0.001380  0.002291   0.149118  0.169971    0.001718    0.002191
# 2.1875        0.002072  0.002605   0.155321  0.170687    0.002235    0.002318
# 2.5000        0.002387  0.002911   0.160930  0.170833    0.002923    0.002563
# 2.8125        0.003148  0.003182   0.167963  0.171354    0.003552    0.002965
# 3.1250        0.003474  0.003525   0.176379  0.171966    0.004191    0.003364
# 3.4375        0.004766  0.004046   0.185415  0.172394    0.005276    0.003770
# 3.7500        0.005323  0.004548   0.195723  0.172571    0.006184    0.004142
# 4.0625        0.006880  0.004933   0.208132  0.173313    0.008012    0.004463
# 4.3750        0.008931  0.005445   0.221829  0.173558    0.009960    0.005121
# 4.6875        0.011392  0.005501   0.240165  0.174282    0.012943    0.005404
# 5.0000        0.014783  0.006115   0.261971  0.174742    0.016055    0.005834
# 5.3125        0.018435  0.006473   0.289198  0.175135    0.021991    0.006177
# 5.6250        0.027521  0.007006   0.324643  0.175628    0.028059    0.006869
# 5.9375        0.037442  0.007565   0.374370  0.176212    0.040705    0.007302
# 6.2500        0.053754  0.007988   0.441189  0.176719    0.061510    0.007547
# 6.5625        0.090705  0.008559   0.553530  0.177189    0.102920    0.008136
# 6.8750        0.171538  0.009067   0.753294  0.177925    0.198468    0.008557
# 7.1875        0.503397  0.009521   1.281441  0.178343    0.578482    0.009121
# 7.5000        7.961516  0.010170   6.530763  0.178938    6.317825    0.009650
# 7.8125       30.749166  0.010741  33.764922  0.179651   31.236514    0.010214
# 8.1250        0.481706  0.011294  60.928590  0.179733    1.966149    0.010535
# 8.4375        0.637791  0.010892  59.389579  0.180259    0.736072    0.010309
# 8.7500        0.729447  0.010637  57.077693  0.179467    0.800297    0.010939
# 9.0625        1.387869  0.011864  55.170110  0.179611    1.017704    0.011125
# 9.3750        1.427637  0.011394  53.422906  0.179778    0.702078    0.010707

# %% [markdown]
# Cases with $B > 1$.

# %%
filename = "B10_N250_K20_Beta0.5_Lambda_0568_167.csv"

d1 = pd.read_csv(cases[0] + filename)
avg1 = d1.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std1 = d1.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg1.columns = ["FIFO-Q", "FIFO-D"]
std1.columns = ["STD-FIFO-Q", "STD-FIFO-D"]

d2 = pd.read_csv(cases[1] + filename)
avg2 = d2.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std2 = d2.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg2.columns = ["R-Q", "R-D"]
std2.columns = ["STD-R-Q", "STD-R-D"]

d3 = pd.read_csv(cases[2] + filename)
avg3 = d3.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std3 = d3.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg3.columns = ["LIFO-Q", "LIFO-D"]
std3.columns = ["STD-LIFO-Q", "STD-LIFO-D"]

db = pd.concat([avg1, std1, avg2, std2, avg3, std3],axis = 1)

# %%
db.to_csv("FB_QDCompare_RFIFOLIFO_B10_N250_K20_Beta05_Lambda_0568_167.csv")

# %% [markdown]
# Another case with $B > 1$

# %%
filename = "B500_N50_K5_Beta0.1_Lambda01_09.csv"

d1 = pd.read_csv(cases[0] + filename)
avg1 = d1.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std1 = d1.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg1.columns = ["FIFO-Q", "FIFO-D"]
std1.columns = ["STD-FIFO-Q", "STD-FIFO-D"]

d2 = pd.read_csv(cases[1] + filename)
avg2 = d2.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std2 = d2.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg2.columns = ["R-Q", "R-D"]
std2.columns = ["STD-R-Q", "STD-R-D"]

d3 = pd.read_csv(cases[2] + filename)
avg3 = d3.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std3 = d3.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg3.columns = ["LIFO-Q", "LIFO-D"]
std3.columns = ["STD-LIFO-Q", "STD-LIFO-D"]

db = pd.concat([avg1, std1, avg2, std2, avg3, std3],axis = 1)

# %%
filename = "B500_N50_K5_Beta0.1_Lambda1_3.csv"

d1 = pd.read_csv(cases[0] + filename)
avg1 = d1.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std1 = d1.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg1.columns = ["FIFO-Q", "FIFO-D"]
std1.columns = ["STD-FIFO-Q", "STD-FIFO-D"]

d2 = pd.read_csv(cases[1] + filename)
avg2 = d2.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std2 = d2.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg2.columns = ["R-Q", "R-D"]
std2.columns = ["STD-R-Q", "STD-R-D"]

d3 = pd.read_csv(cases[2] + filename)
avg3 = d3.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
std3 = d3.groupby("ArrivalRate").std()[["AvgQDelay", "AvgDDelay"]]
avg3.columns = ["LIFO-Q", "LIFO-D"]
std3.columns = ["STD-LIFO-Q", "STD-LIFO-D"]

dc = pd.concat([avg1, std1, avg2, std2, avg3, std3],axis = 1)

# %%
dd = pd.concat([db, dc], axis = 0)

# %%
dd.to_csv("FB_QDCompare_RFIFOLIFO_B500_N50_K5_Beta0.1_Lambda1_3.csv")
