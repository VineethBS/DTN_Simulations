# %%
import pandas as pd

# %%
d = pd.read_csv("B100_N50_K5_Beta0.1_Lambda01_09.csv")

# %%
d.head()
# Out:
#    Run  NumSources  CommnArrivalRate  ArrivalRate  NumCopies  NumRelays  \
# 0    0           1               0.9         0.10          5         50
# 1    0           1               0.9         0.10          5         50
# 2    0           1               0.9         0.15          5         50
# 3    0           1               0.9         0.15          5         50
# 4    0           1               0.9         0.20          5         50
#
#    RelayBuffer  SourceBuffer  MeetingRate  AvgQDelay  StdQDelay  AvgDDelay  \
# 0          100          1000          0.1   1.059595   0.512914   2.825536
# 1          200          1000          0.1   1.066361   0.509911   2.836242
# 2          100          1000          0.1   1.088906   0.538436   2.824722
# 3          200          1000          0.1   1.086445   0.536933   2.824568
# 4          100          1000          0.1   1.132928   0.580447   2.848902
#
#    StdDDelay  FractionDropped
# 0   2.076712              0.0
# ...

# %%
d.groupby(["ArrivalRate"]).mean()
# Out:
#              Run  NumSources  CommnArrivalRate  NumCopies  NumRelays  \
# ArrivalRate
# 0.10           5           1               0.9          5         50
# 0.15           5           1               0.9          5         50
# 0.20           5           1               0.9          5         50
# 0.25           5           1               0.9          5         50
# 0.30           5           1               0.9          5         50
# 0.35           5           1               0.9          5         50
# 0.40           5           1               0.9          5         50
# 0.45           5           1               0.9          5         50
# 0.50           5           1               0.9          5         50
# 0.55           5           1               0.9          5         50
# 0.60           5           1               0.9          5         50
# 0.65           5           1               0.9          5         50
# ...
