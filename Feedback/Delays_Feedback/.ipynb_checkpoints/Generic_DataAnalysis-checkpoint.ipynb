# %%
import pandas as pd

# %%
d = pd.read_csv("N100_Beta0.1_K30_Buffer100-1000.csv")

# %%
d.head()
# Out:
#    Run  NumSources  CommnArrivalRate  ArrivalRate  NumCopies  NumRelays  \
# 0    0           1              0.55        0.740         30        100
# 1    0           1              0.55        0.740         30        100
# 2    0           1              0.55        0.740         30        100
# 3    0           1              0.55        0.740         30        100
# 4    0           1              0.55        0.742         30        100
#
#    RelayBuffer  SourceBuffer  MeetingRate  AvgQDelay  StdQDelay  AvgDDelay  \
# 0          100           500          0.1   8.326713   5.870876   3.677920
# 1          500           500          0.1   8.887142   6.602344   3.672120
# 2          900           500          0.1   8.287712   5.462460   3.736004
# 3         1300           500          0.1   8.319660   5.247207   3.631388
# 4          100           500          0.1   8.427125   5.511326   3.661097
#
#    StdDDelay  FractionDropped
# 0   0.864567              0.0
# ...

# %%
d.groupby(["RelayBuffer","ArrivalRate"]).mean().to_csv("N100_Beta0.1_K30_Buffer100-1000_Stability.csv")
