# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = pd.read_csv('TestN1B1_K3_Beta0.5_Lambda01_09.csv')
a1 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B5_K3_Beta0.5_Lambda01_09.csv')
a5 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B10_K3_Beta0.5_Lambda01_09.csv')
a10 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B50_K3_Beta0.5_Lambda01_09.csv')
a50 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]

# %%
plot(a5["AvgQDelay"], 'b')
plot(a10["AvgQDelay"], 'g')
plot(a50["AvgQDelay"], 'k')

# %%
d = pd.read_csv('TestN1B5_K3_Beta0.5_Rho01_09.csv')
a5 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B10_K3_Beta0.5_Rho01_09.csv')
a10 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B50_K3_Beta0.5_Rho01_09.csv')
a50 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B100_K3_Beta0.5_Rho01_09.csv')
a100 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]

# %%
plot(arange(0.1, 1, 0.1), a10["AvgQDelay"], 'g')
plot(arange(0.1, 1, 0.1), a50["AvgQDelay"], 'k')
plot(arange(0.1, 1, 0.1), a100["AvgQDelay"], 'r')

# %%
plot(a10["AvgQDelay"], 'g')
plot(a50["AvgQDelay"], 'k')
plot(a100["AvgQDelay"], 'r')

# %%
d = pd.read_csv('TestN1B5_K1_Beta0.5_Rho01_09.csv')
a5 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B10_K1_Beta0.5_Rho01_09.csv')
a10 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B50_K1_Beta0.5_Rho01_09.csv')
a50 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]
d = pd.read_csv('TestN1B100_K1_Beta0.5_Rho01_09.csv')
a100 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]

# %%
plot(arange(0.1, 1, 0.1), a5["AvgQDelay"], 'b')
plot(arange(0.1, 1, 0.1), a10["AvgQDelay"], 'g')
plot(arange(0.1, 1, 0.1), a50["AvgQDelay"], 'k')
plot(arange(0.1, 0.95, 0.05), a100["AvgQDelay"], 'r')

# %%
a50
# Out:
#              AvgQDelay  AvgDDelay
# ArrivalRate
# 0.04902       2.214864   2.220183
# 0.09804       2.512858   2.481530
# 0.14706       2.846058   2.827231
# 0.19608       3.287106   3.260799
# 0.24510       3.897327   3.960626
# 0.29412       4.886540   4.818182
# 0.34314       6.289744   6.315709
# 0.39216       9.276050   9.182674
# 0.44118      16.191780  16.131863

# %%
plot(a5["AvgQDelay"], 'b')
plot(a10["AvgQDelay"], 'g')
plot(a50["AvgQDelay"], 'k')
plot(a100["AvgQDelay"], 'r')

# %% [markdown]
# ### This is the behaviour we had observed and identified as an ISSUE. So this happens even for the K = 1, N = 1 case

# %%
d = pd.read_csv('TestN1B100_K1_Beta0.5_Rho99_101.csv')
a100 = d.groupby("ArrivalRate").mean()[["AvgQDelay", "AvgDDelay"]]

# %%
a100
# Out:
#                AvgQDelay  AvgDDelay
# ArrivalRate
# 0.49005        96.440122  69.922274
# 0.53955      2969.326429  92.102786
# 0.58905      7041.601306  99.863033

# %%
d = pd.read_csv('TestN1_K1_Beta0.5_Rho09_BufferVar.csv')
a = d.groupby('RelayBuffer').mean()[["AvgQDelay", "AvgDDelay"]]
plot(a.ix[10:])

# %%
d = pd.read_csv('TestN1_K1_Beta0.5_Lambda0409_BufferVar.csv')
a = d.groupby('RelayBuffer').mean()[["AvgQDelay", "AvgDDelay"]]
plot(a.ix[10:])

# %% [markdown]
# ### The issue is that there is monotonicity (monotonically decreasing) in the average queue length for a fixed arrival rate as the buffer size B increases. However as a function of $\rho$ the average queue length is not monotonic in the buffer size.
